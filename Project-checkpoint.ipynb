# %% [markdown]
# <h1 style="text-align:left;font-size:130%">
#     Experimental Software Engineering
#     <span style="float:right">
#         2024/2025
#     </span>
# </h1>
#
# # <center>**Gym Activity** </center>
#
# ### **<center> Realized by: </center>**
# <center> Hasan Çinar, Letícia Cascais</center>

# %% [markdown]
# -------

# %% [markdown]
# # Contents
#
# 1. [Data Evaluation](#Avaliação-dados)
# 2. [Simultaneous Analysis](#juntar)
# 3. [Predictive Modeling](#previsoes)

# %% [markdown]
# -------

# %%
#Necessary imports
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# -------

# %%
#Import file
gym_activity = pd.read_csv('gym_activity_cleaned.csv', sep = ',')
sns.set_theme(style="whitegrid")

# %% [markdown]
# -------

# %% [markdown]
# <a id="Avaliação-dados"></a>
# # <center>Data Evaluation</center>

# %%
#Data available in our Dataset
gym_activity
# Out:
#      age  gender  weight_kg  height_m  max_bpm  avg_bpm  resting_bpm  \
# 0     56    Male       88.3      1.71      180      157           60
# 1     46  Female       74.9      1.53      179      151           66
# 2     32  Female       68.1      1.66      167      122           54
# 3     25    Male       53.2      1.70      190      164           56
# 4     38    Male       46.1      1.79      188      158           68
# ..   ...     ...        ...       ...      ...      ...          ...
# 968   24    Male       87.1      1.74      187      158           67
# 969   25    Male       66.6      1.61      184      166           56
# 970   59  Female       60.4      1.76      194      120           53
# 971   32    Male      126.4      1.83      198      146           62
# 972   46    Male       88.7      1.63      166      146           66
#
#      duration_h  calories_burned workout_type  fat_percentage  water_l  \
# ...

# %%
gym_activity.columns
# Out:
# Index(['age', 'gender', 'weight_kg', 'height_m', 'max_bpm', 'avg_bpm',
#        'resting_bpm', 'duration_h', 'calories_burned', 'workout_type',
#        'fat_percentage', 'water_l', 'workout_frequency_daysweek',
#        'experience_level', 'bmi'],
#       dtype='object')

# %% [markdown]
# Moving on to analyzing **each column**

# %% [markdown]
# -------

# %% [markdown]
# ## <center>Types of Features</center>

# %% [markdown]
# **Categorical Features:**
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as Nominal Variables.
#
# Categorical Features in the dataset: **gender, workout_type**.
#
# **Ordinal Features:**
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values.
#
# Ordinal Features in the dataset: **experience_level, workout_frequency_daysweek**.
#
# **Continous Feature:**
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# Ordinal Features in the dataset: **age, weight_kg, height_m, max_bpm, avg_bpm, resting_bpm, duration_h, calories_burned, fat_percentage, water_l, bmi**.

# %% [markdown]
# <a id="juntar"></a>
# # <center>Simultaneous Analysis</center>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=gym_activity, x='duration_h', y='calories_burned', hue='workout_type', palette='viridis', alpha=0.8)
plt.title('Burned Calories vs. Duration', fontsize=16)
plt.xlabel('Duration (hours)', fontsize=12)
plt.ylabel('Burned Calories', fontsize=12)
plt.legend(title='Workout Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# There is a clear positive correlation between workout duration and calories burned.
# Different types of workouts (Yoga, HIIT, etc.) exhibit distinct patterns of calories burned for the same duration.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=gym_activity, x='workout_frequency_daysweek', y='resting_bpm', palette='coolwarm')
plt.title('BPM vs. Workout Frequency (days/week)', fontsize=16)
plt.xlabel('Workout Frequency (days/week)', fontsize=12)
plt.ylabel('BPM', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Resting heart rate tends to be lower in individuals who train more days per week, indicating better physical conditioning.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=gym_activity, x='workout_type', y='calories_burned', palette='pastel')
plt.title('Calories burned per Workout Type', fontsize=16)
plt.xlabel('Workout Type', fontsize=12)
plt.ylabel('Burned Calories', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# HIIT and Strength training show greater variability in calorie burn, while Yoga has a narrower range.

# %% [markdown]
# -------

# %% [markdown]
# <a id="previsoes"></a>
# # <center>Predictive Models</center>

# %% [markdown]
# The project focuses on predictive modeling to understand patterns of behavior, specifically related to calorie burn, which is a key metric for physical well-being.

# %% [markdown]
# -------

# %% [markdown]
# <a id="previsao1"></a>
# # Regression algorithms

# %%
y = gym_activity[['calories_burned']]
X = pd.get_dummies(gym_activity.drop(columns=['calories_burned']), drop_first=True)

# Split the data into training and test sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#Decision Tree Regressor

#Train the Decision Tree model
DTR_model = DecisionTreeRegressor()
DTR_model.fit(X_train, y_train)
DTR_y_pred = DTR_model.predict(X_test)

#Decision Tree Metrics
print("\nDecision Tree Regressor:")
print('R^2 Score: ', metrics.r2_score(y_test, DTR_y_pred))
print('Mean Squared Error (MSE): ', metrics.mean_squared_error(y_test, DTR_y_pred))
print('Mean Absolute Error (MAE): ', metrics.mean_absolute_error(y_test, DTR_y_pred))
print('Root Mean Squared Error (RMSE): ', np.sqrt(metrics.mean_squared_error(y_test, DTR_y_pred)))

#Plotting Predictions vs Actual Values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, DTR_y_pred, alpha=0.6, edgecolor='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title("Decision Tree Regressor: Predictions vs Actual")
plt.xlabel("Actual Calories Burned")
plt.ylabel("Predicted Calories Burned")
plt.grid(True)
plt.show()
# Out:
# Decision Tree Regressor:
# R^2 Score:  0.9283241114862736
# Mean Squared Error (MSE):  4675.748717948718
# Mean Absolute Error (MAE):  51.34871794871795
# Root Mean Squared Error (RMSE):  68.3794466045808

# %% [markdown]
# The red line represents the ideal scenario where predictions perfectly match the actual values.

# %% [markdown]
# -------

# %%
#K-Nearest Neighbors Regressor

#Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#Train the KNN model
knn_regressor = KNeighborsRegressor(n_neighbors=5)
knn_regressor.fit(X_train_scaled, y_train)
K_y_pred = knn_regressor.predict(X_test_scaled)

#KNN Metrics
print("\nK-Nearest Neighbors Regressor:")
print('R^2 Score: ', metrics.r2_score(y_test, K_y_pred))
print('Mean Squared Error (MSE): ', metrics.mean_squared_error(y_test, K_y_pred))
print('Mean Absolute Error (MAE): ', metrics.mean_absolute_error(y_test, K_y_pred))
print('Root Mean Squared Error (RMSE): ', np.sqrt(metrics.mean_squared_error(y_test, K_y_pred)))

#Plotting Predictions vs Actual Values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, K_y_pred, alpha=0.6, edgecolor='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title("K-Nearest Neighbors Regressor: Predictions vs Actual")
plt.xlabel("Actual Calories Burned")
plt.ylabel("Predicted Calories Burned")
plt.grid(True)
plt.show()
# Out:
# K-Nearest Neighbors Regressor:
# R^2 Score:  0.7356848568776241
# Mean Squared Error (MSE):  17242.49558974359
# Mean Absolute Error (MAE):  104.3097435897436
# Root Mean Squared Error (RMSE):  131.31068345623515

# %% [markdown]
# -------

# %%
#Linear Regression

#Train the Linear Regression model
LR_model = LinearRegression()
LR_model.fit(X_train, y_train)
LR_y_pred = LR_model.predict(X_test)

#Linear Regression Metrics
print("\nLinear Regression:")
print('R^2 Score: ', metrics.r2_score(y_test, LR_y_pred))
print('Mean Squared Error (MSE): ', metrics.mean_squared_error(y_test, LR_y_pred))
print('Mean Absolute Error (MAE): ', metrics.mean_absolute_error(y_test, LR_y_pred))
print('Root Mean Squared Error (RMSE): ', np.sqrt(metrics.mean_squared_error(y_test, LR_y_pred)))

#Plotting Predictions vs Actual Values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, LR_y_pred, alpha=0.6, edgecolor='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title("Linear Regression: Predictions vs Actual")
plt.xlabel("Actual Calories Burned")
plt.ylabel("Predicted Calories Burned")
plt.grid(True)
plt.show()
# Out:
# Linear Regression:
# R^2 Score:  0.977970434939795
# Mean Squared Error (MSE):  1437.0901110977607
# Mean Absolute Error (MAE):  29.862876084859213
# Root Mean Squared Error (RMSE):  37.908971380106856

# %% [markdown]
# LInear Regression it's the best model because:
# It has the highest R² Score (97.8%), indicating the best fit to the data; It has the lowest errors across all metrics (MSE, MAE, RMSE), making it the most precise and reliable - Linear Regression is ideal for well-being and self-discipline where precision and interpretability are crucial. It provides actionable insights into the relationships between features and calorie burn.

# %% [markdown]
# ### Confusion matrices

# %%
#Figure configuration
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Decision Tree Classifier Heatmap
sns.heatmap(confusion_matrix(y_test, DTC_y_pred), square=True, annot=True, cbar=True, fmt='d', ax=axes[0])
axes[0].set_title('Decision Tree Classifier')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('True')

#KNN Heatmap
sns.heatmap(confusion_matrix(y_test, KNN_y_pred), square=True, annot=True, cbar=True, fmt='d', ax=axes[1])
axes[1].set_title('KNN Classifier')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('True')

#Linear Regression Heatmap
sns.heatmap(confusion_matrix(y_test, LR_y_pred_labels), square=True, annot=True, cbar=True, fmt='d', ax=axes[2])
axes[2].set_title('Linear Regression')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('True')

plt.tight_layout()
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# The Decision Tree classifier consistently provides the highest accuracy and balanced performance across all classes. It is the most reliable model for predicting calorie burn levels and interpreting well-being behaviors.

# %% [markdown]
# Best Model for Balanced Predictions: Decision Tree is the most robust and balanced model based on the confusion matrix. It effectively captures all classes and minimizes misclassifications.
#
# Best Model for Simplicity: Linear Regression performs well overall, with higher accuracy and fewer complexities, but struggles in minority class predictions.
#
# KNN: The weakest performer due to higher misclassifications and sensitivity to imbalanced data.
#
# Conclusion:
# If balanced performance across all classes is critical, go with Decision Tree. If simplicity and interpretability are more important, choose Linear Regression.
